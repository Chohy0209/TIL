# %%
# Out:
# 가위 바위 보중에 하나를 내세요:가위
# 3

# %%
#1사용자 입력과 random 함수를 사용하여, 사용자와 컴퓨터가 대결하는 가위바위 보 게임을 만들어 보자 입력: 문자열 출력: 문자열 결과 반환
import random
user_in=input("가위 바위 보중에 하나를 내세요:")


def u_rsp(user_in):

    if user_in=='가위':
        a=1
        return a
    elif user_in=='바위':
        a=2
        return a
    elif user_in=='보':
        a=3
        return a
    else:
        print("가위 바위 보 중에 하나를 내주세요")

a=u_rsp(user_in)
com_rsp=random.randint(1,3)
if a!=1 and a!=2 and a!=3:
    print("다시 실행하세요")
elif com_rsp==1 and a==1:
    print('비겼습니다')
elif com_rsp==1 and a==2:
    print("이겼습니다.")
elif com_rsp==1 and a==3:
    print('졌습니다')
elif com_rsp==2 and a==1:
    print("졌습니다")
elif com_rsp==2 and a==2:
    print('비겼습니다')
elif com_rsp==2 and a==3:
    print('이겼습니다.')
elif com_rsp==3 and a==1:
    print("이겼습니다")
elif com_rsp==3 and a==2:
    print('졌습니다')
else:
    print("비겼습니다")
# Out:
# 가위 바위 보중에 하나를 내세요:묵찌빠
# 가위 바위 보 중에 하나를 내주세요
# 다시 실행하세요

# %%
hap=0
for i in str(2**1000):
    hap+=int(i)
print(hap)
# Out:
# 1366

# %%
transtwo=[]
user_num,trans=map(int,input("숫자와 변환하고 싶은 진수를 입력해주세요.").split())
if trans ==2 :
    while True:
        transtwo.append(user_num%2)
        user_num=user_num//2
        if user_num==1:
            transtwo.append(user_num)
            break
transtwo.reverse()
print(*transtwo,sep="")
# Out:
# 숫자와 변환하고 싶은 진수를 입력해주세요.23310 2
# 101101100001110

# %%
user_url=input("사이트를 입력하세요")
def make_url(user_url):
    print("www.",user_url,".com" ,sep="")
make_url(user_url)
# Out:
# 사이트를 입력하세요naver
# www.naver.com

# %%
def make_list():
    user_s=input("문자열을 입력")
    make_list=[i for i in user_s]
    print(make_list)
make_list()
# Out:
# 문자열을 입력abcd
# ['a', 'b', 'c', 'd']
