# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
from torch.utils.data import TensorDataset # 텐서데이터셋
from torch.utils.data import DataLoader # 데이터로더

# %%
x_train  =  torch.FloatTensor([[73,  80,  75],
                               [93,  88,  93],
                               [89,  91,  90],
                               [96,  98,  100],
                               [73,  66,  70]])
y_train  =  torch.FloatTensor([[152],  [185],  [180],  [196],  [142]])

# %%
dataset = TensorDataset(x_train, y_train)

# %%
dataloader = DataLoader(dataset, batch_size=2, shuffle=True) #shuffle=True로 하면 매 에포크 마다 데이터의 순서가 바뀜

# %%
model = nn.Linear(3,1) #입력차원3, 출력차원1
optimizer = torch.optim.SGD(model.parameters(), lr=1e-5)

# %%
nb_epochs = 20
for epoch in range(nb_epochs + 1):
  for batch_idx, samples in enumerate(dataloader):
    # print(batch_idx)
    # print(samples)
    x_train, y_train = samples
    # H(x) 계산
    prediction = model(x_train)

    # cost 계산
    cost = F.mse_loss(prediction, y_train)

    # cost로 H(x) 계산
    optimizer.zero_grad()
    cost.backward()
    optimizer.step()

    print('Epoch {:4d}/{} Batch {}/{} Cost: {:.6f}'.format(
        epoch, nb_epochs, batch_idx+1, len(dataloader),
        cost.item()
        ))
# Out:
# Epoch    0/20 Batch 1/3 Cost: 19090.425781
# Epoch    0/20 Batch 2/3 Cost: 7878.618164
# Epoch    0/20 Batch 3/3 Cost: 3560.506836
# Epoch    1/20 Batch 1/3 Cost: 498.836731
# Epoch    1/20 Batch 2/3 Cost: 171.173111
# Epoch    1/20 Batch 3/3 Cost: 14.038363
# Epoch    2/20 Batch 1/3 Cost: 27.181129
# Epoch    2/20 Batch 2/3 Cost: 9.551046
# Epoch    2/20 Batch 3/3 Cost: 0.421917
# Epoch    3/20 Batch 1/3 Cost: 6.829092
# Epoch    3/20 Batch 2/3 Cost: 1.675207
# Epoch    3/20 Batch 3/3 Cost: 2.046931
# Epoch    4/20 Batch 1/3 Cost: 0.872368
# Epoch    4/20 Batch 2/3 Cost: 3.576010
# Epoch    4/20 Batch 3/3 Cost: 1.884168
# Epoch    5/20 Batch 1/3 Cost: 2.624857
# Epoch    5/20 Batch 2/3 Cost: 2.103534
# Epoch    5/20 Batch 3/3 Cost: 0.057040
# Epoch    6/20 Batch 1/3 Cost: 1.859389
# Epoch    6/20 Batch 2/3 Cost: 2.586844
# Epoch    6/20 Batch 3/3 Cost: 2.799096
# Epoch    7/20 Batch 1/3 Cost: 1.688810
# Epoch    7/20 Batch 2/3 Cost: 3.343462
# Epoch    7/20 Batch 3/3 Cost: 0.225602
# ...

# %%
# 임의의 입력 [73, 80, 75]를 선언
new_var =  torch.FloatTensor([[73, 80, 75]])
# 입력한 값 [73, 80, 75]에 대해서 예측값 y를 리턴받아서 pred_y에 저장
pred_y = model(new_var)
print("훈련 후 입력이 73, 80, 75일 때의 예측값 :", pred_y)
# Out:
# 훈련 후 입력이 73, 80, 75일 때의 예측값 : tensor([[153.8561]], grad_fn=<AddmmBackward0>)

# %%
#추상클래스->클래스 상속 받아 orveride(재정의) 추상클래스의 동물에 먹는다 라는 함수가 있다면 -> 사람 클래스에서 동물 클래스를 상속받아 씹어먹는다라는 함수로 재정의
