# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
scientists=pd.read_csv("../../data/data/scientists.csv")

# %%
ages = scientists['Age']

# %%
print(ages.max())
# Out:
# 90

# %%
print(ages.mean())
# Out:
# 59.125

# %%
print(ages[ages > ages.mean()])
# Out:
# 1    61
# 2    90
# 3    66
# 7    77
# Name: Age, dtype: int64

# %%
print(ages + ages)
# Out:
# 0     74
# 1    122
# 2    180
# 3    132
# 4    112
# 5     90
# 6     82
# 7    154
# Name: Age, dtype: int64

# %%
print(ages * ages)
# Out:
# 0    1369
# 1    3721
# 2    8100
# 3    4356
# 4    3136
# 5    2025
# 6    1681
# 7    5929
# Name: Age, dtype: int64

# %%
print(ages + 100)
# Out:
# 0    137
# 1    161
# 2    190
# 3    166
# 4    156
# 5    145
# 6    141
# 7    177
# Name: Age, dtype: int64

# %%
print(ages * 2)
# Out:
# 0     74
# 1    122
# 2    180
# 3    132
# 4    112
# 5     90
# 6     82
# 7    154
# Name: Age, dtype: int64

# %%
print(scientists[scientists['Age'] > scientists['Age'].mean()])
# Out:
#                    Name        Born        Died  Age     Occupation
# 1        William Gosset  1876-06-13  1937-10-16   61   Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90          Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66        Chemist
# 7          Johann Gauss  1777-04-30  1855-02-23   77  Mathematician

# %%
print(scientists *2)
# Out:
#                                        Name                  Born  \
# 0        Rosaline FranklinRosaline Franklin  1920-07-251920-07-25
# 1              William GossetWilliam Gosset  1876-06-131876-06-13
# 2  Florence NightingaleFlorence Nightingale  1820-05-121820-05-12
# 3                    Marie CurieMarie Curie  1867-11-071867-11-07
# 4                Rachel CarsonRachel Carson  1907-05-271907-05-27
# 5                        John SnowJohn Snow  1813-03-151813-03-15
# 6                    Alan TuringAlan Turing  1912-06-231912-06-23
# 7                  Johann GaussJohann Gauss  1777-04-301777-04-30
#
#                    Died  Age                            Occupation
# 0  1958-04-161958-04-16   74                        ChemistChemist
# 1  1937-10-161937-10-16  122              StatisticianStatistician
# 2  1910-08-131910-08-13  180                            NurseNurse
# 3  1934-07-041934-07-04  132                        ChemistChemist
# ...

# %%
scientists["Born"]
# Out:
# 0    1920-07-25
# 1    1876-06-13
# 2    1820-05-12
# 3    1867-11-07
# 4    1907-05-27
# 5    1813-03-15
# 6    1912-06-23
# 7    1777-04-30
# Name: Born, dtype: object

# %%
born_datetime = pd.to_datetime(scientists['Born'], format='%Y-%m-%d') 
print(born_datetime)
# Out:
# 0   1920-07-25
# 1   1876-06-13
# 2   1820-05-12
# 3   1867-11-07
# 4   1907-05-27
# 5   1813-03-15
# 6   1912-06-23
# 7   1777-04-30
# Name: Born, dtype: datetime64[ns]

# %%
died_datetime = pd.to_datetime(scientists['Died'], format='%Y-%m-%d') # objects였던 dtype을 날짜형식으로 바꿈
print(died_datetime)
# Out:
# 0   1958-04-16
# 1   1937-10-16
# 2   1910-08-13
# 3   1934-07-04
# 4   1964-04-14
# 5   1858-06-16
# 6   1954-06-07
# 7   1855-02-23
# Name: Died, dtype: datetime64[ns]

# %%
scientists['born_dt'], scientists['died_dt'] = (born_datetime, died_datetime)
print(scientists.head())
# Out:
#                    Name        Born        Died  Age    Occupation    born_dt  \
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37       Chemist 1920-07-25
# 1        William Gosset  1876-06-13  1937-10-16   61  Statistician 1876-06-13
# 2  Florence Nightingale  1820-05-12  1910-08-13   90         Nurse 1820-05-12
# 3           Marie Curie  1867-11-07  1934-07-04   66       Chemist 1867-11-07
# 4         Rachel Carson  1907-05-27  1964-04-14   56     Biologist 1907-05-27
#
#      died_dt
# 0 1958-04-16
# 1 1937-10-16
# 2 1910-08-13
# 3 1934-07-04
# 4 1964-04-14

# %%
scientists.shape
# Out:
# (8, 7)

# %%
scientists.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        8 non-null      object
#  1   Born        8 non-null      object
#  2   Died        8 non-null      object
#  3   Age         8 non-null      int64
#  4   Occupation  8 non-null      object
#  5   born_dt     8 non-null      datetime64[ns]
#  6   died_dt     8 non-null      datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(4)
# memory usage: 580.0+ bytes

# %%
scientists['age_days']=scientists['died_dt']-scientists['born_dt'] #scientists['died_dt']-scientists['born_dt'] #생존 기간(일)출력
scientists
# Out:
#                    Name        Born        Died  Age          Occupation  \
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   61        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   77       Mathematician
#
#      born_dt    died_dt   age_days
# 0 1920-07-25 1958-04-16 13779 days
# 1 1876-06-13 1937-10-16 22404 days
# 2 1820-05-12 1910-08-13 32964 days
# 3 1867-11-07 1934-07-04 24345 days
# 4 1907-05-27 1964-04-14 20777 days
# 5 1813-03-15 1858-06-16 16529 days
# 6 1912-06-23 1954-06-07 15324 days
# ...

# %%
scientists
scientists.drop('age_days',axis=1) # 열 삭제
# Out:
#                    Name        Born        Died  Age          Occupation  \
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   61        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   77       Mathematician
#
#      born_dt    died_dt
# 0 1920-07-25 1958-04-16
# 1 1876-06-13 1937-10-16
# 2 1820-05-12 1910-08-13
# 3 1867-11-07 1934-07-04
# 4 1907-05-27 1964-04-14
# 5 1813-03-15 1858-06-16
# 6 1912-06-23 1954-06-07
# 7 1777-04-30 1855-02-23

# %%
import seaborn as sns 
anscombe = sns.load_dataset("anscombe") 
print(anscombe)
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %%
dataset_1=anscombe[anscombe['dataset']=='I']
dataset_1
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68

# %%
dataset_2 = anscombe[anscombe['dataset'] == 'II'] 
dataset_3 = anscombe[anscombe['dataset'] == 'III'] 
dataset_4 = anscombe[anscombe['dataset'] == 'IV']

# %%
dataset_1.describe() # 단순히 기술통계가 같다고 해서 같은데이터 라고 할 수 없음. 데이터의 '분포' 가 다를 수 있음
# Out:
#                x          y
# count  11.000000  11.000000
# mean    9.000000   7.500909
# std     3.316625   2.031568
# min     4.000000   4.260000
# 25%     6.500000   6.315000
# 50%     9.000000   7.580000
# 75%    11.500000   8.570000
# max    14.000000  10.840000

# %%
dataset_2.describe()
# Out:
#                x          y
# count  11.000000  11.000000
# mean    9.000000   7.500909
# std     3.316625   2.031657
# min     4.000000   3.100000
# 25%     6.500000   6.695000
# 50%     9.000000   8.140000
# 75%    11.500000   8.950000
# max    14.000000   9.260000

# %%
plt.plot(dataset_1['x'], dataset_1['y'],'o') # 점으로 보기

# %%
fig = plt.figure()
axes1 = fig.add_subplot(2, 2, 1)
axes2 = fig.add_subplot(2, 2, 2)
axes3 = fig.add_subplot(2, 2, 3)
axes4 = fig.add_subplot(2, 2, 4)

# %%
axes1.plot(dataset_1['x'], dataset_1['y'], 'o') 
axes2.plot(dataset_2['x'], dataset_2['y'], 'o') 
axes3.plot(dataset_3['x'], dataset_3['y'], 'o') 
axes4.plot(dataset_4['x'], dataset_4['y'], 'o')
# 위 네개 데이터가 기술통계 값이 다 동일
fig

# %%
tips = sns.load_dataset("tips") 
print(tips.head())
print(type(tips))
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# <class 'pandas.core.frame.DataFrame'>

# %%
fig = plt.figure() 
axes1 = fig.add_subplot(1, 1, 1)

# %%
axes1.hist(tips['total_bill'], bins=10) 
axes1.set_title('Histogram of Total Bill')
axes1.set_xlabel('Frequency') 
axes1.set_ylabel('Total Bill')
fig

# %%
scatter_plot = plt.figure() 
axes1 = scatter_plot.add_subplot(1, 1, 1) 
axes1.scatter(tips['total_bill'], tips['tip']) 
axes1.set_title('Scatterplot of Total Bill vs Tip') 
axes1.set_xlabel('Total Bill') 
axes1.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %%
boxplot = plt.figure() 
axes1 = boxplot.add_subplot(1, 1, 1) 

axes1.boxplot( 
    [tips[tips['sex'] == 'Female']['tip'], 
     tips[tips['sex'] == 'Male']['tip']], 
    labels=['Female', 'Male'])


axes1.set_xlabel('Sex') 
axes1.set_ylabel('Tip') 
axes1.set_title('Boxplot of Tips by Sex')
# Out:
# Text(0.5, 1.0, 'Boxplot of Tips by Sex')

# %%
#네모박스= q1과 q3 (1사분위수와 3사분위수) 네모박스 안의 값=interquartile Range( IQR ), q3*1.5*IQR = maximum값 그 이상이면 outliers(극단값)
# q1-1.5*IQR = minimum 값 그 이하이면 outliers(극단값)
# 극단값은 데이터 양 끝의 0.35% 정도로 잡힘
df1=pd.read_csv("../../data/data/concat_1.csv")
df1
# Out:
#     A   B   C   D
# 0  a0  b0  c0  d0
# 1  a1  b1  c1  d1
# 2  a2  b2  c2  d2
# 3  a3  b3  c3  d3

# %%
df2=pd.read_csv("../../data/data/concat_2.csv")
df2
# Out:
#     A   B   C   D
# 0  a4  b4  c4  d4
# 1  a5  b5  c5  d5
# 2  a6  b6  c6  d6
# 3  a7  b7  c7  d7

# %%
df3=pd.read_csv("../../data/data/concat_3.csv")
df3
# Out:
#      A    B    C    D
# 0   a8   b8   c8   d8
# 1   a9   b9   c9   d9
# 2  a10  b10  c10  d10
# 3  a11  b11  c11  d11

# %%
row_concat = pd.concat([df1, df2, df3]) 
print(row_concat)
# Out:
#      A    B    C    D
# 0   a0   b0   c0   d0
# 1   a1   b1   c1   d1
# 2   a2   b2   c2   d2
# 3   a3   b3   c3   d3
# 0   a4   b4   c4   d4
# 1   a5   b5   c5   d5
# 2   a6   b6   c6   d6
# 3   a7   b7   c7   d7
# 0   a8   b8   c8   d8
# 1   a9   b9   c9   d9
# 2  a10  b10  c10  d10
# 3  a11  b11  c11  d11

# %%
gapminder=pd.read_csv("../../data/data/gapminder.tsv", sep='\t')
gapminder
#전세계인에 대해 연도별 기대수명의 평균
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
life_exp=gapminder.groupby(gapminder.year).lifeExp.mean()

# %%
life_exp.index
life_exp.index>2000
life_exp[life_exp.index>2000]
# Out:
# year
# 2002    65.694923
# 2007    67.007423
# Name: lifeExp, dtype: float64

# %%
pd.read_csv('../../data/data/country_timeseries.csv')
# Out:
#            Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0      1/5/2015  289        2776.0            NaN            10030.0
# 1      1/4/2015  288        2775.0            NaN             9780.0
# 2      1/3/2015  287        2769.0         8166.0             9722.0
# 3      1/2/2015  286           NaN         8157.0                NaN
# 4    12/31/2014  284        2730.0         8115.0             9633.0
# ..          ...  ...           ...            ...                ...
# 117   3/27/2014    5         103.0            8.0                6.0
# 118   3/26/2014    4          86.0            NaN                NaN
# 119   3/25/2014    3          86.0            NaN                NaN
# 120   3/24/2014    2          86.0            NaN                NaN
# 121   3/22/2014    0          49.0            NaN                NaN
#
#      Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# 0              NaN            NaN                 NaN          NaN
# ...

# %%
ebola=pd.read_csv('../../data/data/country_timeseries.csv')
ebola
# Out:
#            Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0      1/5/2015  289        2776.0            NaN            10030.0
# 1      1/4/2015  288        2775.0            NaN             9780.0
# 2      1/3/2015  287        2769.0         8166.0             9722.0
# 3      1/2/2015  286           NaN         8157.0                NaN
# 4    12/31/2014  284        2730.0         8115.0             9633.0
# ..          ...  ...           ...            ...                ...
# 117   3/27/2014    5         103.0            8.0                6.0
# 118   3/26/2014    4          86.0            NaN                NaN
# 119   3/25/2014    3          86.0            NaN                NaN
# 120   3/24/2014    2          86.0            NaN                NaN
# 121   3/22/2014    0          49.0            NaN                NaN
#
#      Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# 0              NaN            NaN                 NaN          NaN
# ...

# %%
ebola.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 122 non-null    object
#  1   Day                  122 non-null    int64
#  2   Cases_Guinea         93 non-null     float64
#  3   Cases_Liberia        83 non-null     float64
#  4   Cases_SierraLeone    87 non-null     float64
#  5   Cases_Nigeria        38 non-null     float64
#  6   Cases_Senegal        25 non-null     float64
#  7   Cases_UnitedStates   18 non-null     float64
#  8   Cases_Spain          16 non-null     float64
#  9   Cases_Mali           12 non-null     float64
#  10  Deaths_Guinea        92 non-null     float64
#  11  Deaths_Liberia       81 non-null     float64
#  12  Deaths_SierraLeone   87 non-null     float64
#  13  Deaths_Nigeria       38 non-null     float64
#  14  Deaths_Senegal       22 non-null     float64
# ...

# %%
ebola.count()
# Out:
# Date                   122
# Day                    122
# Cases_Guinea            93
# Cases_Liberia           83
# Cases_SierraLeone       87
# Cases_Nigeria           38
# Cases_Senegal           25
# Cases_UnitedStates      18
# Cases_Spain             16
# Cases_Mali              12
# Deaths_Guinea           92
# Deaths_Liberia          81
# Deaths_SierraLeone      87
# Deaths_Nigeria          38
# Deaths_Senegal          22
# Deaths_UnitedStates     18
# Deaths_Spain            16
# Deaths_Mali             12
# dtype: int64

# %%
ebola.shape
num_rows = ebola.shape[0]
num_missing = num_rows - ebola.count()
num_missing
# Out:
# Date                     0
# Day                      0
# Cases_Guinea            29
# Cases_Liberia           39
# Cases_SierraLeone       35
# Cases_Nigeria           84
# Cases_Senegal           97
# Cases_UnitedStates     104
# Cases_Spain            106
# Cases_Mali             110
# Deaths_Guinea           30
# Deaths_Liberia          41
# Deaths_SierraLeone      35
# Deaths_Nigeria          84
# Deaths_Senegal         100
# Deaths_UnitedStates    104
# Deaths_Spain           106
# Deaths_Mali            110
# dtype: int64

# %%
ebola.Cases_Guinea.value_counts()
# Out:
# Cases_Guinea
# 86.0      3
# 495.0     2
# 112.0     2
# 390.0     2
# 408.0     1
#          ..
# 1199.0    1
# 1298.0    1
# 1350.0    1
# 1472.0    1
# 49.0      1
# Name: count, Length: 88, dtype: int64

# %%
ebola.Cases_Guinea.value_counts(dropna=False)
# Out:
# Cases_Guinea
# NaN       29
# 86.0       3
# 495.0      2
# 112.0      2
# 390.0      2
#           ..
# 1199.0     1
# 1298.0     1
# 1350.0     1
# 1472.0     1
# 49.0       1
# Name: count, Length: 89, dtype: int64

# %%
ebola.interpolate()# 보간법 nan값을 사이값으로 채워넣음
# Out:
# C:\Users\master\AppData\Local\Temp\ipykernel_13392\4098302585.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   ebola.interpolate()
#            Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0      1/5/2015  289        2776.0            NaN            10030.0
# 1      1/4/2015  288        2775.0            NaN             9780.0
# 2      1/3/2015  287        2769.0         8166.0             9722.0
# 3      1/2/2015  286        2749.5         8157.0             9677.5
# 4    12/31/2014  284        2730.0         8115.0             9633.0
# ..          ...  ...           ...            ...                ...
# 117   3/27/2014    5         103.0            8.0                6.0
# 118   3/26/2014    4          86.0            8.0                6.0
# 119   3/25/2014    3          86.0            8.0                6.0
# ...

# %%
ebola.dropna()
# Out:
#           Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 19  11/18/2014  241        2047.0         7082.0             6190.0
#
#     Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  Cases_Mali  \
# 19           20.0            1.0                 4.0          1.0         6.0
#
#     Deaths_Guinea  Deaths_Liberia  Deaths_SierraLeone  Deaths_Nigeria  \
# 19         1214.0          2963.0              1267.0             8.0
#
#     Deaths_Senegal  Deaths_UnitedStates  Deaths_Spain  Deaths_Mali
# 19             0.0                  1.0           0.0          6.0

# %%
ebola['Cases_multiple'] = ebola['Cases_Guinea'] + ebola['Cases_Liberia'] + ebola['Cases_SierraLeone']

# %%
ebola_subset = ebola.loc[:, ['Cases_Guinea', 'Cases_Liberia', 'Cases_SierraLeone', 'Cases_multiple']]
ebola_subset
# Out:
#      Cases_Guinea  Cases_Liberia  Cases_SierraLeone  Cases_multiple
# 0          2776.0            NaN            10030.0             NaN
# 1          2775.0            NaN             9780.0             NaN
# 2          2769.0         8166.0             9722.0         20657.0
# 3             NaN         8157.0                NaN             NaN
# 4          2730.0         8115.0             9633.0         20478.0
# ..            ...            ...                ...             ...
# 117         103.0            8.0                6.0           117.0
# 118          86.0            NaN                NaN             NaN
# 119          86.0            NaN                NaN             NaN
# 120          86.0            NaN                NaN             NaN
# 121          49.0            NaN                NaN             NaN
#
# [122 rows x 4 columns]

# %%
pew=pd.read_csv('../../data/data/pew.csv')
pew
# Out:
#                    religion  <$10k  $10-20k  $20-30k  $30-40k  $40-50k  \
# 0                  Agnostic     27       34       60       81       76
# 1                   Atheist     12       27       37       52       35
# 2                  Buddhist     27       21       30       34       33
# 3                  Catholic    418      617      732      670      638
# 4        Don’t know/refused     15       14       15       11       10
# 5          Evangelical Prot    575      869     1064      982      881
# 6                     Hindu      1        9        7        9       11
# 7   Historically Black Prot    228      244      236      238      197
# 8         Jehovah's Witness     20       27       24       24       21
# 9                    Jewish     19       19       25       25       30
# 10            Mainline Prot    289      495      619      655      651
# 11                   Mormon     29       40       48       51       56
# ...

# %%
pd.melt(pew) #기존 구조를 녹이고 (melt) 벨류에 데이터 값이 variable에 열 인덱스들이 옴
# Out:
#                variable               value
# 0              religion            Agnostic
# 1              religion             Atheist
# 2              religion            Buddhist
# 3              religion            Catholic
# 4              religion  Don’t know/refused
# ..                  ...                 ...
# 193  Don't know/refused                  73
# 194  Don't know/refused                  18
# 195  Don't know/refused                  71
# 196  Don't know/refused                   8
# 197  Don't know/refused                 597
#
# [198 rows x 2 columns]

# %%
pd.melt(pew, id_vars='religion')
# Out:
#                   religion            variable  value
# 0                 Agnostic               <$10k     27
# 1                  Atheist               <$10k     12
# 2                 Buddhist               <$10k     27
# 3                 Catholic               <$10k    418
# 4       Don’t know/refused               <$10k     15
# ..                     ...                 ...    ...
# 175               Orthodox  Don't know/refused     73
# 176        Other Christian  Don't know/refused     18
# 177           Other Faiths  Don't know/refused     71
# 178  Other World Religions  Don't know/refused      8
# 179           Unaffiliated  Don't know/refused    597
#
# [180 rows x 3 columns]

# %%
pd.melt(pew, id_vars='religion', var_name='income', value_name='count') #고정하려는 열 값을 id_vars에 나머지 열들은 행으로 변환
# Out:
#                   religion              income  count
# 0                 Agnostic               <$10k     27
# 1                  Atheist               <$10k     12
# 2                 Buddhist               <$10k     27
# 3                 Catholic               <$10k    418
# 4       Don’t know/refused               <$10k     15
# ..                     ...                 ...    ...
# 175               Orthodox  Don't know/refused     73
# 176        Other Christian  Don't know/refused     18
# 177           Other Faiths  Don't know/refused     71
# 178  Other World Religions  Don't know/refused      8
# 179           Unaffiliated  Don't know/refused    597
#
# [180 rows x 3 columns]

# %%
billboard=pd.read_csv('../../data/data/billboard.csv')
billboard
# Out:
#      year            artist                    track  time date.entered  wk1  \
# 0    2000             2 Pac  Baby Don't Cry (Keep...  4:22   2000-02-26   87
# 1    2000           2Ge+her  The Hardest Part Of ...  3:15   2000-09-02   91
# 2    2000      3 Doors Down               Kryptonite  3:53   2000-04-08   81
# 3    2000      3 Doors Down                    Loser  4:24   2000-10-21   76
# 4    2000          504 Boyz            Wobble Wobble  3:35   2000-04-15   57
# ..    ...               ...                      ...   ...          ...  ...
# 312  2000       Yankee Grey     Another Nine Minutes  3:10   2000-04-29   86
# 313  2000  Yearwood, Trisha          Real Live Woman  3:55   2000-04-01   85
# 314  2000   Ying Yang Twins  Whistle While You Tw...  4:19   2000-03-18   95
# 315  2000     Zombie Nation            Kernkraft 400  3:30   2000-09-02   99
# 316  2000   matchbox twenty                     Bent  4:12   2000-04-29   60
#
# ...

# %%
billboard.melt(id_vars=['year','artist','track','time','date.entered'],var_name='week',value_name='rating')
# Out:
#        year            artist                    track  time date.entered  \
# 0      2000             2 Pac  Baby Don't Cry (Keep...  4:22   2000-02-26
# 1      2000           2Ge+her  The Hardest Part Of ...  3:15   2000-09-02
# 2      2000      3 Doors Down               Kryptonite  3:53   2000-04-08
# 3      2000      3 Doors Down                    Loser  4:24   2000-10-21
# 4      2000          504 Boyz            Wobble Wobble  3:35   2000-04-15
# ...     ...               ...                      ...   ...          ...
# 24087  2000       Yankee Grey     Another Nine Minutes  3:10   2000-04-29
# 24088  2000  Yearwood, Trisha          Real Live Woman  3:55   2000-04-01
# 24089  2000   Ying Yang Twins  Whistle While You Tw...  4:19   2000-03-18
# 24090  2000     Zombie Nation            Kernkraft 400  3:30   2000-09-02
# 24091  2000   matchbox twenty                     Bent  4:12   2000-04-29
#
#        week  rating
# 0       wk1    87.0
# 1       wk1    91.0
# ...

# %%
ebola
ebola.columns
# Out:
# Index(['Date', 'Day', 'Cases_Guinea', 'Cases_Liberia', 'Cases_SierraLeone',
#        'Cases_Nigeria', 'Cases_Senegal', 'Cases_UnitedStates', 'Cases_Spain',
#        'Cases_Mali', 'Deaths_Guinea', 'Deaths_Liberia', 'Deaths_SierraLeone',
#        'Deaths_Nigeria', 'Deaths_Senegal', 'Deaths_UnitedStates',
#        'Deaths_Spain', 'Deaths_Mali', 'Cases_multiple'],
#       dtype='object')

# %%
ebola.iloc[:5, [0,1,2,3,10,11] ]
# Out:
#          Date  Day  Cases_Guinea  Cases_Liberia  Deaths_Guinea  Deaths_Liberia
# 0    1/5/2015  289        2776.0            NaN         1786.0             NaN
# 1    1/4/2015  288        2775.0            NaN         1781.0             NaN
# 2    1/3/2015  287        2769.0         8166.0         1767.0          3496.0
# 3    1/2/2015  286           NaN         8157.0            NaN          3496.0
# 4  12/31/2014  284        2730.0         8115.0         1739.0          3471.0

# %%
ebola
# Out:
#            Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0      1/5/2015  289        2776.0            NaN            10030.0
# 1      1/4/2015  288        2775.0            NaN             9780.0
# 2      1/3/2015  287        2769.0         8166.0             9722.0
# 3      1/2/2015  286           NaN         8157.0                NaN
# 4    12/31/2014  284        2730.0         8115.0             9633.0
# ..          ...  ...           ...            ...                ...
# 117   3/27/2014    5         103.0            8.0                6.0
# 118   3/26/2014    4          86.0            NaN                NaN
# 119   3/25/2014    3          86.0            NaN                NaN
# 120   3/24/2014    2          86.0            NaN                NaN
# 121   3/22/2014    0          49.0            NaN                NaN
#
#      Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# 0              NaN            NaN                 NaN          NaN
# ...

# %%
pd.melt(ebola, id_vars=('Date','Day'))
# Out:
#             Date  Day        variable   value
# 0       1/5/2015  289    Cases_Guinea  2776.0
# 1       1/4/2015  288    Cases_Guinea  2775.0
# 2       1/3/2015  287    Cases_Guinea  2769.0
# 3       1/2/2015  286    Cases_Guinea     NaN
# 4     12/31/2014  284    Cases_Guinea  2730.0
# ...          ...  ...             ...     ...
# 2069   3/27/2014    5  Cases_multiple   117.0
# 2070   3/26/2014    4  Cases_multiple     NaN
# 2071   3/25/2014    3  Cases_multiple     NaN
# 2072   3/24/2014    2  Cases_multiple     NaN
# 2073   3/22/2014    0  Cases_multiple     NaN
#
# [2074 rows x 4 columns]

# %%
ebola_long = pd.melt(ebola, id_vars=['Date', 'Day'])
print(ebola_long.head())
# Out:
#          Date  Day      variable   value
# 0    1/5/2015  289  Cases_Guinea  2776.0
# 1    1/4/2015  288  Cases_Guinea  2775.0
# 2    1/3/2015  287  Cases_Guinea  2769.0
# 3    1/2/2015  286  Cases_Guinea     NaN
# 4  12/31/2014  284  Cases_Guinea  2730.0

# %%
variable_split = ebola_long.variable.str.split('_')
variable_split
# Out:
# 0         [Cases, Guinea]
# 1         [Cases, Guinea]
# 2         [Cases, Guinea]
# 3         [Cases, Guinea]
# 4         [Cases, Guinea]
#               ...
# 2069    [Cases, multiple]
# 2070    [Cases, multiple]
# 2071    [Cases, multiple]
# 2072    [Cases, multiple]
# 2073    [Cases, multiple]
# Name: variable, Length: 2074, dtype: object

# %%
variable_split.str[0]
# Out:
# 0       Cases
# 1       Cases
# 2       Cases
# 3       Cases
# 4       Cases
#         ...
# 2069    Cases
# 2070    Cases
# 2071    Cases
# 2072    Cases
# 2073    Cases
# Name: variable, Length: 2074, dtype: object

# %%
variable_split.str.get(0)# 이런식으로 명시적 표현도 가능
# Out:
# 0       Cases
# 1       Cases
# 2       Cases
# 3       Cases
# 4       Cases
#         ...
# 2069    Cases
# 2070    Cases
# 2071    Cases
# 2072    Cases
# 2073    Cases
# Name: variable, Length: 2074, dtype: object

# %%
ebola_long['status']=variable_split.str.get(0)
ebola_long[ebola_long['status']=='Deaths']
# Out:
#             Date  Day       variable   value  status
# 976     1/5/2015  289  Deaths_Guinea  1786.0  Deaths
# 977     1/4/2015  288  Deaths_Guinea  1781.0  Deaths
# 978     1/3/2015  287  Deaths_Guinea  1767.0  Deaths
# 979     1/2/2015  286  Deaths_Guinea     NaN  Deaths
# 980   12/31/2014  284  Deaths_Guinea  1739.0  Deaths
# ...          ...  ...            ...     ...     ...
# 1947   3/27/2014    5    Deaths_Mali     NaN  Deaths
# 1948   3/26/2014    4    Deaths_Mali     NaN  Deaths
# 1949   3/25/2014    3    Deaths_Mali     NaN  Deaths
# 1950   3/24/2014    2    Deaths_Mali     NaN  Deaths
# 1951   3/22/2014    0    Deaths_Mali     NaN  Deaths
#
# [976 rows x 5 columns]

# %%
tips=sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.dtypes #category:범주형
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
tips['sex_str']=tips.sex.astype(str)

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size sex_str
# 0         16.99  1.01  Female     No   Sun  Dinner     2  Female
# 1         10.34  1.66    Male     No   Sun  Dinner     3    Male
# 2         21.01  3.50    Male     No   Sun  Dinner     3    Male
# 3         23.68  3.31    Male     No   Sun  Dinner     2    Male
# 4         24.59  3.61  Female     No   Sun  Dinner     4  Female
# ..          ...   ...     ...    ...   ...     ...   ...     ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3    Male
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2  Female
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2    Male
# 242       17.82  1.75    Male     No   Sat  Dinner     2    Male
# 243       18.78  3.00  Female     No  Thur  Dinner     2  Female
#
# [244 rows x 8 columns]

# %%
tips.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# sex_str         object
# dtype: object

# %%
tips['total_bill_str']=tips.total_bill.astype(str)

# %%
tips.dtypes
# Out:
# total_bill         float64
# tip                float64
# sex               category
# smoker            category
# day               category
# time              category
# size                 int64
# sex_str             object
# total_bill_str      object
# dtype: object

# %%
d1 = '40°' 
m1 = "46'" 
s1 = '52.837"' 
u1 = 'N'

d2 = '73°' 
m2 = "58'" 
s2 = '26.302"' 
u2 = 'W'

# %%
coords = ' '.join([d1, m1, s1, u1, d2, m2, s2, u2])
print(coords)
# Out:
# 40° 46' 52.837" N 73° 58' 26.302" W

# %%
multi_str = """Guard: What? Ridden on a horse?
King Arthur: Yes!
Guard: You're using coconuts!
King Arthur: What?
Guard: You've got ... coconut[s] and you're bangin' 'em together. 
""" 
print(multi_str)
# Out:
# Guard: What? Ridden on a horse?
# King Arthur: Yes!
# Guard: You're using coconuts!
# King Arthur: What?
# Guard: You've got ... coconut[s] and you're bangin' 'em together.

# %%
multi_str_split=multi_str.splitlines() # 문자열을 줄 단위로 나누기
print(multi_str_split)
# Out:
# ['Guard: What? Ridden on a horse?', 'King Arthur: Yes!', "Guard: You're using coconuts!", 'King Arthur: What?', "Guard: You've got ... coconut[s] and you're bangin' 'em together. "]

# %%
multi_str
# Out:
# "Guard: What? Ridden on a horse?\nKing Arthur: Yes!\nGuard: You're using coconuts!\nKing Arthur: What?\nGuard: You've got ... coconut[s] and you're bangin' 'em together. \n"

# %%
 multi_str.replace("Guard: ", "")
# Out:
# "What? Ridden on a horse?\nKing Arthur: Yes!\nYou're using coconuts!\nKing Arthur: What?\nYou've got ... coconut[s] and you're bangin' 'em together. \n"

# %%
df = pd.read_csv('../../data/data/gapminder.tsv', sep='\t')

# %%
df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
years=df.year.unique() #연도를 중복되지 않게 출력
print(years)
# Out:
# [1952 1957 1962 1967 1972 1977 1982 1987 1992 1997 2002 2007]

# %%
#1952년 자료만 추출하여 y1952 변에 저장
y1952=df[df.year==1952]
y1952
# Out:
#                  country continent  year  lifeExp       pop    gdpPercap
# 0            Afghanistan      Asia  1952   28.801   8425333   779.445314
# 12               Albania    Europe  1952   55.230   1282697  1601.056136
# 24               Algeria    Africa  1952   43.077   9279525  2449.008185
# 36                Angola    Africa  1952   30.015   4232095  3520.610273
# 48             Argentina  Americas  1952   62.485  17876956  5911.315053
# ...                  ...       ...   ...      ...       ...          ...
# 1644             Vietnam      Asia  1952   40.412  26246839   605.066492
# 1656  West Bank and Gaza      Asia  1952   43.160   1030585  1515.592329
# 1668         Yemen, Rep.      Asia  1952   32.548   4963829   781.717576
# 1680              Zambia    Africa  1952   42.038   2672000  1147.388831
# 1692            Zimbabwe    Africa  1952   48.451   3080907   406.884115
#
# [142 rows x 6 columns]

# %%
y1952=df.loc[df.year==1952,:]
y1952
# Out:
#                  country continent  year  lifeExp       pop    gdpPercap
# 0            Afghanistan      Asia  1952   28.801   8425333   779.445314
# 12               Albania    Europe  1952   55.230   1282697  1601.056136
# 24               Algeria    Africa  1952   43.077   9279525  2449.008185
# 36                Angola    Africa  1952   30.015   4232095  3520.610273
# 48             Argentina  Americas  1952   62.485  17876956  5911.315053
# ...                  ...       ...   ...      ...       ...          ...
# 1644             Vietnam      Asia  1952   40.412  26246839   605.066492
# 1656  West Bank and Gaza      Asia  1952   43.160   1030585  1515.592329
# 1668         Yemen, Rep.      Asia  1952   32.548   4963829   781.717576
# 1680              Zambia    Africa  1952   42.038   2672000  1147.388831
# 1692            Zimbabwe    Africa  1952   48.451   3080907   406.884115
#
# [142 rows x 6 columns]

# %%
tips.groupby('size').filter(lambda x: x['size'].count()>=30) #filter함수 : ()안에 있는 함수로 필터링 하는것
# Out:
#      total_bill   tip     sex smoker   day    time  size sex_str  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2  Female
# 1         10.34  1.66    Male     No   Sun  Dinner     3    Male
# 2         21.01  3.50    Male     No   Sun  Dinner     3    Male
# 3         23.68  3.31    Male     No   Sun  Dinner     2    Male
# 4         24.59  3.61  Female     No   Sun  Dinner     4  Female
# ..          ...   ...     ...    ...   ...     ...   ...     ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3    Male
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2  Female
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2    Male
# 242       17.82  1.75    Male     No   Sat  Dinner     2    Male
# 243       18.78  3.00  Female     No  Thur  Dinner     2  Female
#
#     total_bill_str
# 0            16.99
# 1            10.34
# 2            21.01
# 3            23.68
# 4            24.59
# ..             ...
# 239          29.03
# 240          27.18
# ...

# %%
tip10=tips.sample(10, random_state=3) # 데이터에서 샘플을 뽑음.
tip10
# Out:
#      total_bill   tip     sex smoker   day    time  size sex_str  \
# 14        14.83  3.02  Female     No   Sun  Dinner     2  Female
# 134       18.26  3.25  Female     No  Thur   Lunch     2  Female
# 126        8.52  1.48    Male     No  Thur   Lunch     2    Male
# 6          8.77  2.00    Male     No   Sun  Dinner     2    Male
# 61        13.81  2.00    Male    Yes   Sat  Dinner     2    Male
# 133       12.26  2.00  Female     No  Thur   Lunch     2  Female
# 125       29.80  4.20  Female     No  Thur   Lunch     6  Female
# 182       45.35  3.50    Male    Yes   Sun  Dinner     3    Male
# 43         9.68  1.32    Male     No   Sun  Dinner     2    Male
# 143       27.05  5.00  Female     No  Thur   Lunch     6  Female
#
#     total_bill_str
# 14           14.83
# 134          18.26
# 126           8.52
# 6             8.77
# 61           13.81
# 133          12.26
# 125           29.8
# 182          45.35
# 43            9.68
# 143          27.05

# %%
grouped=tip10.groupby('sex')
grouped
# Out:
# C:\Users\master\AppData\Local\Temp\ipykernel_13392\4269514207.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped=tip10.groupby('sex')

# %%
grouped.groups
# Out:
# {'Male': [126, 6, 61, 182, 43], 'Female': [14, 134, 133, 125, 143]}

# %%
grouped.mean(numeric_only=True) #수치에 해당되는 데이터에 대해서만 평균을 구하게 하는 옵션
# Out:
#         total_bill    tip  size
# sex
# Male        17.226  2.060   2.2
# Female      20.440  3.494   3.6

# %%
date_str = ["2018, 1, 1", "2018, 1, 4", "2018, 1, 5", "2018, 1, 6"]
idx = pd.to_datetime(date_str)
idx
# Out:
# DatetimeIndex(['2018-01-01', '2018-01-04', '2018-01-05', '2018-01-06'], dtype='datetime64[ns]', freq=None)

# %%
date_str
# Out:
# ['2018, 1, 1', '2018, 1, 4', '2018, 1, 5', '2018, 1, 6']

# %%
np.random.seed(0)
s = pd.Series(np.random.randn(4), index=idx) # 인덱스에 날짜 데이터형식이 들어감
s
# Out:
# 2018-01-01    1.764052
# 2018-01-04    0.400157
# 2018-01-05    0.978738
# 2018-01-06    2.240893
# dtype: float64

# %%
pd.date_range("2024-02-28","2024-06-03")
# Out:
# DatetimeIndex(['2024-02-28', '2024-02-29', '2024-03-01', '2024-03-02',
#                '2024-03-03', '2024-03-04', '2024-03-05', '2024-03-06',
#                '2024-03-07', '2024-03-08', '2024-03-09', '2024-03-10',
#                '2024-03-11', '2024-03-12', '2024-03-13', '2024-03-14',
#                '2024-03-15', '2024-03-16', '2024-03-17', '2024-03-18',
#                '2024-03-19', '2024-03-20', '2024-03-21', '2024-03-22',
#                '2024-03-23', '2024-03-24', '2024-03-25', '2024-03-26',
#                '2024-03-27', '2024-03-28', '2024-03-29', '2024-03-30',
#                '2024-03-31', '2024-04-01', '2024-04-02', '2024-04-03',
#                '2024-04-04', '2024-04-05', '2024-04-06', '2024-04-07',
#                '2024-04-08', '2024-04-09', '2024-04-10', '2024-04-11',
#                '2024-04-12', '2024-04-13', '2024-04-14', '2024-04-15',
#                '2024-04-16', '2024-04-17', '2024-04-18', '2024-04-19',
# ...

# %%
pd.date_range(start="2024-4-1", periods=50) #50개의 데이터를 추출
# Out:
# DatetimeIndex(['2024-04-01', '2024-04-02', '2024-04-03', '2024-04-04',
#                '2024-04-05', '2024-04-06', '2024-04-07', '2024-04-08',
#                '2024-04-09', '2024-04-10', '2024-04-11', '2024-04-12',
#                '2024-04-13', '2024-04-14', '2024-04-15', '2024-04-16',
#                '2024-04-17', '2024-04-18', '2024-04-19', '2024-04-20',
#                '2024-04-21', '2024-04-22', '2024-04-23', '2024-04-24',
#                '2024-04-25', '2024-04-26', '2024-04-27', '2024-04-28',
#                '2024-04-29', '2024-04-30', '2024-05-01', '2024-05-02',
#                '2024-05-03', '2024-05-04', '2024-05-05', '2024-05-06',
#                '2024-05-07', '2024-05-08', '2024-05-09', '2024-05-10',
#                '2024-05-11', '2024-05-12', '2024-05-13', '2024-05-14',
#                '2024-05-15', '2024-05-16', '2024-05-17', '2024-05-18',
#                '2024-05-19', '2024-05-20'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range(start="2024-4-1", periods=50, freq='H')
# Out:
# DatetimeIndex(['2024-04-01 00:00:00', '2024-04-01 01:00:00',
#                '2024-04-01 02:00:00', '2024-04-01 03:00:00',
#                '2024-04-01 04:00:00', '2024-04-01 05:00:00',
#                '2024-04-01 06:00:00', '2024-04-01 07:00:00',
#                '2024-04-01 08:00:00', '2024-04-01 09:00:00',
#                '2024-04-01 10:00:00', '2024-04-01 11:00:00',
#                '2024-04-01 12:00:00', '2024-04-01 13:00:00',
#                '2024-04-01 14:00:00', '2024-04-01 15:00:00',
#                '2024-04-01 16:00:00', '2024-04-01 17:00:00',
#                '2024-04-01 18:00:00', '2024-04-01 19:00:00',
#                '2024-04-01 20:00:00', '2024-04-01 21:00:00',
#                '2024-04-01 22:00:00', '2024-04-01 23:00:00',
#                '2024-04-02 00:00:00', '2024-04-02 01:00:00',
#                '2024-04-02 02:00:00', '2024-04-02 03:00:00',
#                '2024-04-02 04:00:00', '2024-04-02 05:00:00',
# ...

# %%
pd.date_range("2024-6-3", "2024-12-31", freq="W") #일요일 주 단위로 날짜데이터 생성
# Out:
# DatetimeIndex(['2024-06-09', '2024-06-16', '2024-06-23', '2024-06-30',
#                '2024-07-07', '2024-07-14', '2024-07-21', '2024-07-28',
#                '2024-08-04', '2024-08-11', '2024-08-18', '2024-08-25',
#                '2024-09-01', '2024-09-08', '2024-09-15', '2024-09-22',
#                '2024-09-29', '2024-10-06', '2024-10-13', '2024-10-20',
#                '2024-10-27', '2024-11-03', '2024-11-10', '2024-11-17',
#                '2024-11-24', '2024-12-01', '2024-12-08', '2024-12-15',
#                '2024-12-22', '2024-12-29'],
#               dtype='datetime64[ns]', freq='W-SUN')

# %%
np.random.seed(0)
ts = pd.Series(np.random.randn(4), index=pd.date_range(
    "2024-8-1", periods=4, freq="M"))#각각의 달의 마지막 일
ts
# Out:
# 2024-08-31    1.764052
# 2024-09-30    0.400157
# 2024-10-31    0.978738
# 2024-11-30    2.240893
# Freq: M, dtype: float64

# %%
ts.shift(-1) #데이터가 한칸씩 위로 올라감
# Out:
# 2024-08-31    0.400157
# 2024-09-30    0.978738
# 2024-10-31    2.240893
# 2024-11-30         NaN
# Freq: M, dtype: float64

# %%
ts = pd.Series(np.random.randn(100), index=pd.date_range(
    "2024-1-1", periods=100, freq="D"))
ts
# Out:
# 2024-01-01   -1.173123
# 2024-01-02    1.943621
# 2024-01-03   -0.413619
# 2024-01-04   -0.747455
# 2024-01-05    1.922942
#                 ...
# 2024-04-05    1.336528
# 2024-04-06   -0.369182
# 2024-04-07   -0.239379
# 2024-04-08    1.099660
# 2024-04-09    0.655264
# Freq: D, Length: 100, dtype: float64

# %%
ts.resample('W').groups
# Out:
# {Timestamp('2024-01-07 00:00:00'): 7,
#  Timestamp('2024-01-14 00:00:00'): 14,
#  Timestamp('2024-01-21 00:00:00'): 21,
#  Timestamp('2024-01-28 00:00:00'): 28,
#  Timestamp('2024-02-04 00:00:00'): 35,
#  Timestamp('2024-02-11 00:00:00'): 42,
#  Timestamp('2024-02-18 00:00:00'): 49,
#  Timestamp('2024-02-25 00:00:00'): 56,
#  Timestamp('2024-03-03 00:00:00'): 63,
#  Timestamp('2024-03-10 00:00:00'): 70,
#  Timestamp('2024-03-17 00:00:00'): 77,
#  Timestamp('2024-03-24 00:00:00'): 84,
#  Timestamp('2024-03-31 00:00:00'): 91,
#  Timestamp('2024-04-07 00:00:00'): 98,
#  Timestamp('2024-04-14 00:00:00'): 100}

# %%
ts.resample("W").mean() #주 단위로 데이터를 그룹으로 묶은 후 mean함수 적용됨
# Out:
# 2024-01-07    0.697206
# 2024-01-14    0.468797
# 2024-01-21    0.249052
# 2024-01-28    0.301938
# 2024-02-04    0.023198
# 2024-02-11    0.283486
# 2024-02-18   -0.096136
# 2024-02-25   -0.446708
# 2024-03-03    0.155312
# 2024-03-10    0.200799
# 2024-03-17   -0.376808
# 2024-03-24   -0.895860
# 2024-03-31   -0.129493
# 2024-04-07    0.616422
# 2024-04-14    0.877462
# Freq: W-SUN, dtype: float64

# %%
s = pd.Series(pd.date_range("2020-12-25", periods=100, freq="D")) # 날짜형식 데이터
s
# Out:
# 0    2020-12-25
# 1    2020-12-26
# 2    2020-12-27
# 3    2020-12-28
# 4    2020-12-29
#         ...
# 95   2021-03-30
# 96   2021-03-31
# 97   2021-04-01
# 98   2021-04-02
# 99   2021-04-03
# Length: 100, dtype: datetime64[ns]

# %%
s.dt.year # 날짜형식 데이터로 되어있는 시리즈에서 dt함수 적용
#s.year은 에러가 뜸
# Out:
# 0     2020
# 1     2020
# 2     2020
# 3     2020
# 4     2020
#       ...
# 95    2021
# 96    2021
# 97    2021
# 98    2021
# 99    2021
# Length: 100, dtype: int32

# %%
s.dt.weekday
# Out:
# 0     4
# 1     5
# 2     6
# 3     0
# 4     1
#      ..
# 95    1
# 96    2
# 97    3
# 98    4
# 99    5
# Length: 100, dtype: int32

# %%
s.dt.strftime("%Y년 %m월 %d일") # 날짜형식 데이터를  문자형식 데이터로 변환하는 함수
# Out:
# 0     2020년 12월 25일
# 1     2020년 12월 26일
# 2     2020년 12월 27일
# 3     2020년 12월 28일
# 4     2020년 12월 29일
#           ...
# 95    2021년 03월 30일
# 96    2021년 03월 31일
# 97    2021년 04월 01일
# 98    2021년 04월 02일
# 99    2021년 04월 03일
# Length: 100, dtype: object

# %%
from datetime import datetime

# %%
datetime.now()
# Out:
# datetime.datetime(2024, 6, 3, 13, 30, 56, 476258)

# %%
datetime.today()
# Out:
# datetime.datetime(2024, 6, 3, 13, 32, 30, 422978)

# %%
ebola.dtypes
# Out:
# Date                    object
# Day                      int64
# Cases_Guinea           float64
# Cases_Liberia          float64
# Cases_SierraLeone      float64
# Cases_Nigeria          float64
# Cases_Senegal          float64
# Cases_UnitedStates     float64
# Cases_Spain            float64
# Cases_Mali             float64
# Deaths_Guinea          float64
# Deaths_Liberia         float64
# Deaths_SierraLeone     float64
# Deaths_Nigeria         float64
# Deaths_Senegal         float64
# Deaths_UnitedStates    float64
# Deaths_Spain           float64
# Deaths_Mali            float64
# Cases_multiple         float64
# dtype: object

# %%
ebola['date_dt']=pd.to_datetime(ebola['Date'])
ebola
# Out:
#            Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0      1/5/2015  289        2776.0            NaN            10030.0
# 1      1/4/2015  288        2775.0            NaN             9780.0
# 2      1/3/2015  287        2769.0         8166.0             9722.0
# 3      1/2/2015  286           NaN         8157.0                NaN
# 4    12/31/2014  284        2730.0         8115.0             9633.0
# ..          ...  ...           ...            ...                ...
# 117   3/27/2014    5         103.0            8.0                6.0
# 118   3/26/2014    4          86.0            NaN                NaN
# 119   3/25/2014    3          86.0            NaN                NaN
# 120   3/24/2014    2          86.0            NaN                NaN
# 121   3/22/2014    0          49.0            NaN                NaN
#
#      Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# 0              NaN            NaN                 NaN          NaN
# ...

# %%
test_df1 = pd.DataFrame({'order_day':['01/01/15', '02/01/15', '03/01/15']})
test_df1
# Out:
#   order_day
# 0  01/01/15
# 1  02/01/15
# 2  03/01/15

# %%
test_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   order_day  3 non-null      object
# dtypes: object(1)
# memory usage: 156.0+ bytes

# %%
pd.to_datetime(test_df1['order_day'],format="%m/%d/%y") #형식 지정 가능
# Out:
# 0   2015-01-01
# 1   2015-02-01
# 2   2015-03-01
# Name: order_day, dtype: datetime64[ns]

# %%
pd.to_datetime(test_df1['order_day'],format="%d/%m/%y")
# Out:
# 0   2015-01-01
# 1   2015-01-02
# 2   2015-01-03
# Name: order_day, dtype: datetime64[ns]

# %%
pd.to_datetime(test_df1['order_day'],format="%y/%m/%d") # 포맷으로 지정을 해주는게 좋음
# Out:
# 0   2001-01-15
# 1   2002-01-15
# 2   2003-01-15
# Name: order_day, dtype: datetime64[ns]

# %%
test_df2 = pd.DataFrame({'order_day':['01-01-15', '02-01-15', '03-01-15']})
test_df2
# Out:
#   order_day
# 0  01-01-15
# 1  02-01-15
# 2  03-01-15

# %%
pd.to_datetime(test_df2.order_day,format='%d-%m-%y')
# Out:
# 0   2015-01-01
# 1   2015-01-02
# 2   2015-01-03
# Name: order_day, dtype: datetime64[ns]

# %%
pd.read_csv('../../data/data/country_timeseries.csv').info() # 처음부터 date열을 날짜형식으로 읽고싶을때
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 122 non-null    object
#  1   Day                  122 non-null    int64
#  2   Cases_Guinea         93 non-null     float64
#  3   Cases_Liberia        83 non-null     float64
#  4   Cases_SierraLeone    87 non-null     float64
#  5   Cases_Nigeria        38 non-null     float64
#  6   Cases_Senegal        25 non-null     float64
#  7   Cases_UnitedStates   18 non-null     float64
#  8   Cases_Spain          16 non-null     float64
#  9   Cases_Mali           12 non-null     float64
#  10  Deaths_Guinea        92 non-null     float64
#  11  Deaths_Liberia       81 non-null     float64
#  12  Deaths_SierraLeone   87 non-null     float64
#  13  Deaths_Nigeria       38 non-null     float64
#  14  Deaths_Senegal       22 non-null     float64
# ...

# %%
ebola_df=pd.read_csv('../../data/data/country_timeseries.csv',parse_dates=['Date']) #데이트 열을 처음부터 날짜형식으로 읽어옴

ebola_df
# Out:
#           Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0   2015-01-05  289        2776.0            NaN            10030.0
# 1   2015-01-04  288        2775.0            NaN             9780.0
# 2   2015-01-03  287        2769.0         8166.0             9722.0
# 3   2015-01-02  286           NaN         8157.0                NaN
# 4   2014-12-31  284        2730.0         8115.0             9633.0
# ..         ...  ...           ...            ...                ...
# 117 2014-03-27    5         103.0            8.0                6.0
# 118 2014-03-26    4          86.0            NaN                NaN
# 119 2014-03-25    3          86.0            NaN                NaN
# 120 2014-03-24    2          86.0            NaN                NaN
# 121 2014-03-22    0          49.0            NaN                NaN
#
#      Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# 0              NaN            NaN                 NaN          NaN
# ...

# %%
ev.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 122 non-null    datetime64[ns]
#  1   Day                  122 non-null    int64
#  2   Cases_Guinea         93 non-null     float64
#  3   Cases_Liberia        83 non-null     float64
#  4   Cases_SierraLeone    87 non-null     float64
#  5   Cases_Nigeria        38 non-null     float64
#  6   Cases_Senegal        25 non-null     float64
#  7   Cases_UnitedStates   18 non-null     float64
#  8   Cases_Spain          16 non-null     float64
#  9   Cases_Mali           12 non-null     float64
#  10  Deaths_Guinea        92 non-null     float64
#  11  Deaths_Liberia       81 non-null     float64
#  12  Deaths_SierraLeone   87 non-null     float64
#  13  Deaths_Nigeria       38 non-null     float64
#  14  Deaths_Senegal       22 non-null     float64
# ...

# %%
ebola_df.Date.dt.year
ebola_df
# Out:
#           Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0   2015-01-05  289        2776.0            NaN            10030.0
# 1   2015-01-04  288        2775.0            NaN             9780.0
# 2   2015-01-03  287        2769.0         8166.0             9722.0
# 3   2015-01-02  286           NaN         8157.0                NaN
# 4   2014-12-31  284        2730.0         8115.0             9633.0
# ..         ...  ...           ...            ...                ...
# 117 2014-03-27    5         103.0            8.0                6.0
# 118 2014-03-26    4          86.0            NaN                NaN
# 119 2014-03-25    3          86.0            NaN                NaN
# 120 2014-03-24    2          86.0            NaN                NaN
# 121 2014-03-22    0          49.0            NaN                NaN
#
#      Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# 0              NaN            NaN                 NaN          NaN
# ...

# %%
#liberia 발병자 수가 가장 많은날의 날짜
ebola.Date[ebola_df.Cases_Liberia==ebola_df.Cases_Liberia.max()]
# Out:
# 2    1/3/2015
# Name: Date, dtype: object

# %%
pd.to_datetime(ebola_df.Cases_Liberia.max()) #ebola_df.Cases_Liberia.max()의 값 8166을 날짜 형식 값으로 바꾸라는 의미이므로 의미가 다른코드
# Out:
# Timestamp('1970-01-01 00:00:00.000008166')

# %%
banks = pd.read_csv('../../data/data/banklist.csv',parse_dates=['Closing Date','Updated Date']) # 뱅크리스트 데이터중 5,6번 데이터를 날짜형식데이터로 읽어옴
banks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 555 entries, 0 to 554
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Bank Name              555 non-null    object
#  1   City                   555 non-null    object
#  2   ST                     555 non-null    object
#  3   CERT                   555 non-null    int64
#  4   Acquiring Institution  555 non-null    object
#  5   Closing Date           555 non-null    datetime64[ns]
#  6   Updated Date           555 non-null    datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(4)
# memory usage: 30.5+ KB
# C:\Users\master\AppData\Local\Temp\ipykernel_13392\725488196.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# ...

# %%
banks['Closing Date'].dt.quarter # 분기를 확인가능
# Out:
# 0      4
# 1      4
# 2      2
# 3      2
# 4      2
#       ..
# 550    3
# 551    2
# 552    1
# 553    4
# 554    4
# Name: Closing Date, Length: 555, dtype: int32

# %%
banks['Closing Date'].dt.year.value_counts().sort_index()
# Out:
# Closing Date
# 2000      2
# 2001      4
# 2002     11
# 2003      3
# 2004      4
# 2007      3
# 2008     25
# 2009    140
# 2010    157
# 2011     92
# 2012     51
# 2013     24
# 2014     18
# 2015      8
# 2016      5
# 2017      8
# Name: count, dtype: int64

# %%
banks.groupby(banks['Closing Date'].dt.year)['Bank Name'].count()
# Out:
# Closing Date
# 2000      2
# 2001      4
# 2002     11
# 2003      3
# 2004      4
# 2007      3
# 2008     25
# 2009    140
# 2010    157
# 2011     92
# 2012     51
# 2013     24
# 2014     18
# 2015      8
# 2016      5
# 2017      8
# Name: Bank Name, dtype: int64

# %%
pip install pandas_datareader
# Out:
# ...
#    ---------------------------------------- 0.0/109.5 kB ? eta -:--:--
#    --- ------------------------------------ 10.2/109.5 kB ? eta -:--:--
#    ---------------------------------------- 109.5/109.5 kB 1.6 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas_datareader as pdr

# %%
tsla_df=pd.read_csv("TSLA.csv")
tsla_df
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 0   2024-03-04  198.729996  199.750000  186.720001  188.139999  188.139999
# 1   2024-03-05  183.050003  184.589996  177.570007  180.740005  180.740005
# 2   2024-03-06  179.990005  181.580002  173.699997  176.539993  176.539993
# 3   2024-03-07  174.350006  180.039993  173.699997  178.649994  178.649994
# 4   2024-03-08  181.500000  182.729996  174.699997  175.339996  175.339996
# ..         ...         ...         ...         ...         ...         ...
# 58  2024-05-24  174.839996  180.080002  173.729996  179.240005  179.240005
# 59  2024-05-28  176.399994  178.250000  173.160004  176.750000  176.750000
# 60  2024-05-29  174.190002  178.149994  173.929993  176.190002  176.190002
# 61  2024-05-30  178.580002  182.669998  175.380005  178.789993  178.789993
# 62  2024-05-31  178.500000  180.320007  173.820007  178.080002  178.080002
#
#        Volume
# 0   134334900
# 1   119660800
# 2   107920900
# ...

# %%
tsla_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63 entries, 0 to 62
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       63 non-null     object
#  1   Open       63 non-null     float64
#  2   High       63 non-null     float64
#  3   Low        63 non-null     float64
#  4   Close      63 non-null     float64
#  5   Adj Close  63 non-null     float64
#  6   Volume     63 non-null     int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 3.6+ KB

# %%
tsla_df['Date']=pd.to_datetime(tsla_df.Date)
tsla_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63 entries, 0 to 62
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       63 non-null     datetime64[ns]
#  1   Open       63 non-null     float64
#  2   High       63 non-null     float64
#  3   Low        63 non-null     float64
#  4   Close      63 non-null     float64
#  5   Adj Close  63 non-null     float64
#  6   Volume     63 non-null     int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 3.6 KB

# %%
#2010년 6월에 해당되는 자료를 출력

tsla_df[(tsla_df.Date.dt.year==2024)&(tsla_df.Date.dt.month==4)]
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 19 2024-04-01  176.169998  176.750000  170.210007  175.220001  175.220001
# 20 2024-04-02  164.750000  167.690002  163.429993  166.630005  166.630005
# 21 2024-04-03  164.020004  168.820007  163.279999  168.380005  168.380005
# 22 2024-04-04  170.070007  177.190002  168.009995  171.110001  171.110001
# 23 2024-04-05  169.080002  170.860001  160.509995  164.899994  164.899994
# 24 2024-04-08  169.339996  174.500000  167.789993  172.979996  172.979996
# 25 2024-04-09  172.910004  179.220001  171.919998  176.880005  176.880005
# 26 2024-04-10  173.039993  174.929993  170.009995  171.759995  171.759995
# 27 2024-04-11  172.550003  175.880005  168.509995  174.600006  174.600006
# 28 2024-04-12  172.339996  173.809998  170.360001  171.050003  171.050003
# 29 2024-04-15  170.240005  170.690002  161.380005  161.479996  161.479996
# 30 2024-04-16  156.740005  158.190002  153.750000  157.110001  157.110001
# ...

# %%
tsla_df
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2024-03-04  198.729996  199.750000  186.720001  188.139999  188.139999
# 1  2024-03-05  183.050003  184.589996  177.570007  180.740005  180.740005
# 2  2024-03-06  179.990005  181.580002  173.699997  176.539993  176.539993
# 3  2024-03-07  174.350006  180.039993  173.699997  178.649994  178.649994
# 4  2024-03-08  181.500000  182.729996  174.699997  175.339996  175.339996
# ..        ...         ...         ...         ...         ...         ...
# 58 2024-05-24  174.839996  180.080002  173.729996  179.240005  179.240005
# 59 2024-05-28  176.399994  178.250000  173.160004  176.750000  176.750000
# 60 2024-05-29  174.190002  178.149994  173.929993  176.190002  176.190002
# 61 2024-05-30  178.580002  182.669998  175.380005  178.789993  178.789993
# 62 2024-05-31  178.500000  180.320007  173.820007  178.080002  178.080002
#
#        Volume
# 0   134334900
# 1   119660800
# 2   107920900
# 3   102129000
# ...

# %%
tsla_df[['High','Low','Close','Volume']].describe()
# Out:
#              High         Low       Close        Volume
# count   63.000000   63.000000   63.000000  6.300000e+01
# mean   176.046508  169.259840  172.522381  9.465749e+07
# std     10.295189    9.546796    9.792775  3.018888e+07
# min    144.440002  138.800003  142.050003  5.478260e+07
# 25%    172.470001  166.334999  169.829994  7.638145e+07
# 50%    177.190002  171.429993  174.720001  8.600510e+07
# 75%    181.904999  174.705002  177.790001  1.075092e+08
# max    199.750000  186.720001  194.050003  2.438697e+08

# %%
tsla_df.Date[(tsla_df.Open-tsla_df.Close==(tsla_df.Open-tsla_df.Close).value_counts().index[0])]
# Out:
# 16   2024-03-26
# 43   2024-05-03
# Name: Date, dtype: datetime64[ns]
